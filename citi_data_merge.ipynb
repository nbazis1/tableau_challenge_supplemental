# %%
import pandas as pd

# %%
#Read all CSVs
jan22 = pd.read_csv('jan22.csv')
feb22 = pd.read_csv('feb22.csv')
mar22 = pd.read_csv('mar22.csv')
jun22 = pd.read_csv('jun22.csv')
jul22 = pd.read_csv('jul22.csv')
aug22 = pd.read_csv('aug22.csv')

# %%
#Make winter & summer dataframes
winter22 = pd.concat([jan22, feb22, mar22])
summer22 = pd.concat([jun22, jul22, aug22])

# %%
#View dataframes
winter22
summer22

# %%
#Add "season" column, concatenate CSVs 
# Add a 'season' column to each DataFrame
winter22['season'] = 'winter'
summer22['season'] = 'summer'
winter_summer22 = pd.concat([winter22, summer22])
winter_summer22.to_csv('winter_summer22.csv', index=False)

# %%
winter_summer22
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1       BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2       7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3       6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4       E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                  ...            ...                  ...
# 115226  D0F075EEE4354A37  electric_bike  2022-08-03 19:00:22
# 115227  15DE9EFD3E032E69   classic_bike  2022-08-31 18:42:27
# 115228  899BAFD096248F46   classic_bike  2022-08-24 14:26:28
# 115229  AB474610295F3330   classic_bike  2022-08-24 18:50:31
# 115230  1AC620345E6D2BF7   classic_bike  2022-08-31 08:52:20
#
#                    ended_at                start_station_name  \
# 0       2022-01-26 18:51:53              12 St & Sinatra Dr N
# 1       2022-01-28 13:20:23                  Essex Light Rail
# ...
